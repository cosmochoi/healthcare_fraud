# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
outpatient_test = pd.read_csv("./dataset/Test_Outpatientdata-1542969243754.csv")

# %%
outpatient_test.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0      PHY347633              V5832  ...                NaN
# 1      PHY381777               9594  ...                NaN
# ...

# %%
outpatient_train = pd.read_csv("./dataset/Train_Outpatientdata-1542865627584.csv")

# %%
outpatient_train.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# ...

# %%
outpatient = pd.concat((outpatient_train, outpatient_test)).reset_index(drop=True)

# %%
outpatient.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# ...

# %%
#Doctors
outpatient['AttendingPhysician'].nunique()
# Out:
# 91150

# %%
s = outpatient['AttendingPhysician'].value_counts().nlargest(20)
s.plot.bar()
plt.title('Outpatient Medical Doctors')
# Out:
# Text(0.5, 1.0, 'Outpatient Medical Doctors')

# %%
outpatient['BeneID'].nunique()
# Out:
# 144189

# %%
b = outpatient['BeneID'].value_counts().nlargest(20)
b.plot.bar()
plt.title('Outpatients (BeneID)')
# Out:
# Text(0.5, 1.0, 'Outpatients (BeneID)')

# %%
#Each physician works for # many hospitals
hosPhy = pd.DataFrame(outpatient.groupby('AttendingPhysician')['Provider'].nunique()).reset_index()
hosPhy.columns = ["Physician", "Hospitals"]
percent = hosPhy[hosPhy.Hospitals > 1].shape[0]/hosPhy.shape[0] # Percentage of doctors who work for 2 or more hospitals
print("Percent Physicians associated with two or more hospitals:\n" + '%.3f' %percent)
hosPhy[hosPhy.Hospitals > 1]
# Out:
# Percent Physicians associated with two or more hospitals:
# 0.078
#        Physician  Hospitals
# 4      PHY311008          2
# 17     PHY311024          2
# 32     PHY311044          2
# 37     PHY311052          2
# 39     PHY311055          2
# ...          ...        ...
# 91062  PHY434037          2
# 91068  PHY434046          2
# 91078  PHY434061          2
# 91096  PHY434085          2
# 91101  PHY434092          2
#
# [7065 rows x 2 columns]

# %%
#Each patient goes to # many hospitals
hosPat = pd.DataFrame(outpatient.groupby('BeneID')['Provider'].nunique()).reset_index()
hosPat.columns = ['Patient', 'Hospital']
patperc = hosPat[hosPat.Hospital > 1].shape[0]/hosPat.shape[0] # Percentage of doctors who work for 2 or more hospitals
print("Percent Patients that go to two or more hospitals:\n" + '%.3f' %patperc)
hosPat[hosPat.Hospital > 1]
# Out:
# Percent Patients that go to two or more hospitals:
# 0.690
#            Patient  Hospital
# 1       BENE100001         7
# 2       BENE100002        11
# 4       BENE100004         4
# 5       BENE100005         2
# 6       BENE100006         2
# ...            ...       ...
# 144182   BENE99993         3
# 144183   BENE99994         3
# 144186   BENE99997         5
# 144187   BENE99998         2
# 144188   BENE99999         7
#
# [99468 rows x 2 columns]

# %% [markdown]
# ### IMPUTATION

# %%
outpatient[outpatient.isnull().any(axis=1)] 
nullnum = {}
percentage = {}
for element in outpatient.columns:
    nullnum[element] = outpatient[element].isna().sum()
    percentage[element] = outpatient[element].isna().sum()/outpatient[[element]].shape[0] * 100

pd.DataFrame(sorted(percentage.items(), key=lambda x: x[1], reverse=True), columns = ['Feature', '% NA']).head(20)
#sorted(percentage.items(), key=lambda x: x[1], reverse=True)
# Out:
#                   Feature        % NA
# 0      ClmProcedureCode_5  100.000000
# 1      ClmProcedureCode_6  100.000000
# 2      ClmProcedureCode_4   99.999689
# 3      ClmProcedureCode_3   99.999068
# 4      ClmProcedureCode_2   99.993008
# 5      ClmProcedureCode_1   99.969545
# 6     ClmDiagnosisCode_10   99.790857
# 7      ClmDiagnosisCode_9   97.140828
# 8      ClmDiagnosisCode_8   95.580489
# 9      ClmDiagnosisCode_7   93.640087
# 10     ClmDiagnosisCode_6   90.589796
# 11     ClmDiagnosisCode_5   85.656750
# 12     OperatingPhysician   82.562953
# 13  ClmAdmitDiagnosisCode   79.609309
# 14     ClmDiagnosisCode_4   75.750259
# 15         OtherPhysician   62.294392
# 16     ClmDiagnosisCode_3   60.762643
# 17     ClmDiagnosisCode_2   37.774908
# 18     ClmDiagnosisCode_1    2.024774
# 19     AttendingPhysician    0.266013

# %%
outpatient.columns[outpatient.isna().any()].tolist()
#df.columns[df.isna().any()]
# Out:
# ['AttendingPhysician',
#  'OperatingPhysician',
#  'OtherPhysician',
#  'ClmDiagnosisCode_1',
#  'ClmDiagnosisCode_2',
#  'ClmDiagnosisCode_3',
#  'ClmDiagnosisCode_4',
#  'ClmDiagnosisCode_5',
#  'ClmDiagnosisCode_6',
#  'ClmDiagnosisCode_7',
#  'ClmDiagnosisCode_8',
#  'ClmDiagnosisCode_9',
#  'ClmDiagnosisCode_10',
#  'ClmProcedureCode_1',
#  'ClmProcedureCode_2',
#  'ClmProcedureCode_3',
#  'ClmProcedureCode_4',
#  'ClmProcedureCode_5',
#  'ClmProcedureCode_6',
#  'ClmAdmitDiagnosisCode']

# %%
naColumns = outpatient.columns[outpatient.isna().any()].tolist()
for column in naColumns:
    outpatient[column] = outpatient[column].fillna('None')

# %%
outpatient.columns[outpatient.isna().any()].tolist()
outpatient.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117               None
# 1                      80          PHY362868               None
# 2                      10          PHY328821               None
# 3                      40          PHY334319               None
# 4                     200          PHY403831               None
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0           None              78943  ...               None
# 1           None               6115  ...               None
# ...

# %%
outpatient['ClmProcedureCode_5'] = outpatient['ClmProcedureCode_5'].fillna('None')
outpatient['ClmProcedureCode_6'] = outpatient['ClmProcedureCode_6'].fillna('None')
outpatient['ClmProcedureCode_4'] = outpatient['ClmProcedureCode_4'].fillna('None')
outpatient['ClmProcedureCode_3'] = outpatient['ClmProcedureCode_3'].fillna('None')
outpatient['ClmProcedureCode_2'] = outpatient['ClmProcedureCode_2'].fillna('None')
outpatient['ClmProcedureCode_1'] = outpatient['ClmProcedureCode_1'].fillna('None')
outpatient['ClmDiagnosisCode_10'] = outpatient['ClmDiagnosisCode_10'].fillna('None')
outpatient['ClmDiagnosisCode_9'] = outpatient['ClmDiagnosisCode_9'].fillna('None')
outpatient['ClmDiagnosisCode_8'] = outpatient['ClmDiagnosisCode_8'].fillna('None')
outpatient['ClmDiagnosisCode_7'] = outpatient['ClmDiagnosisCode_7'].fillna('None')
outpatient['ClmDiagnosisCode_6'] = outpatient['ClmDiagnosisCode_6'].fillna('None')
outpatient['ClmDiagnosisCode_5'] = outpatient['ClmDiagnosisCode_5'].fillna('None')
outpatient['OperatingPhysician'] = outpatient['OperatingPhysician'].fillna('None')
outpatient['ClmAdmitDiagnosisCode'] = outpatient['ClmAdmitDiagnosisCode'].fillna('None')
outpatient['ClmDiagnosisCode_4'] = outpatient['ClmDiagnosisCode_4'].fillna('None')
outpatient['OtherPhysician'] = outpatient['OtherPhysician'].fillna('None')
outpatient['ClmDiagnosisCode_3'] = outpatient['ClmDiagnosisCode_5'].fillna('None')
outpatient['ClmDiagnosisCode_2'] = outpatient['ClmDiagnosisCode_5'].fillna('None')
outpatient['ClmDiagnosisCode_1'] = outpatient['ClmDiagnosisCode_5'].fillna('None')
outpatient['AttendingPhysician'] = outpatient['AttendingPhysician'].fillna('None')

# %%
outpatient[outpatient.isnull().any(axis=1)] 
2009-10-11
# Out:
# Empty DataFrame
# Columns: [BeneID, ClaimID, ClaimStartDt, ClaimEndDt, Provider, InscClaimAmtReimbursed, AttendingPhysician, OperatingPhysician, OtherPhysician, ClmDiagnosisCode_1, ClmDiagnosisCode_2, ClmDiagnosisCode_3, ClmDiagnosisCode_4, ClmDiagnosisCode_5, ClmDiagnosisCode_6, ClmDiagnosisCode_7, ClmDiagnosisCode_8, ClmDiagnosisCode_9, ClmDiagnosisCode_10, ClmProcedureCode_1, ClmProcedureCode_2, ClmProcedureCode_3, ClmProcedureCode_4, ClmProcedureCode_5, ClmProcedureCode_6, DeductibleAmtPaid, ClmAdmitDiagnosisCode]
# Index: []
#
# [0 rows x 27 columns]

# %%
from datetime import datetime

# %%
ex = datetime.strptime('2009-10-11', '%Y-%m-%d')
print(ex)
# Out:
# 2009-10-11 00:00:00

# %%
from datetime import datetime
outpatient['ClaimStartDt'] = [datetime.strptime(date, '%Y-%m-%d') for date in outpatient.ClaimStartDt]

# %%
outpatient['ClaimEndDt'] = [datetime.strptime(date, '%Y-%m-%d') for date in outpatient.ClaimEndDt]

# %%
outpatient['duration'] = outpatient['ClaimEndDt'] - outpatient['ClaimStartDt']
outpatient['duration'] = list(map(lambda x: x.days, outpatient['duration']))

# %%
outpatient['month'] = list(map(lambda x: x.month, outpatient['ClaimStartDt']))

# %%
outpatient.head()
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11 2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12 2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27 2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06 2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22 2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117               None
# 1                      80          PHY362868               None
# 2                      10          PHY328821               None
# 3                      40          PHY334319               None
# 4                     200          PHY403831               None
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmProcedureCode_1  \
# 0           None              78943  ...               None
# 1           None               6115  ...               None
# ...

# %%
outpatient.dtypes
# Out:
# BeneID                            object
# ClaimID                           object
# ClaimStartDt              datetime64[ns]
# ClaimEndDt                datetime64[ns]
# Provider                          object
# InscClaimAmtReimbursed             int64
# AttendingPhysician                object
# OperatingPhysician                object
# OtherPhysician                    object
# ClmDiagnosisCode_1                object
# ClmDiagnosisCode_2                object
# ClmDiagnosisCode_3                object
# ClmDiagnosisCode_4                object
# ClmDiagnosisCode_5                object
# ClmDiagnosisCode_6                object
# ClmDiagnosisCode_7                object
# ClmDiagnosisCode_8                object
# ClmDiagnosisCode_9                object
# ClmDiagnosisCode_10               object
# ClmProcedureCode_1                object
# ClmProcedureCode_2                object
# ClmProcedureCode_3                object
# ClmProcedureCode_4                object
# ...

# %%
#Each physician works for # many hospitals
hosPhy = pd.DataFrame(outpatient.groupby('AttendingPhysician')['Provider'].nunique()).reset_index()
hosPhy.columns = ["Physician", "Hospitals"]
percent = hosPhy[hosPhy.Hospitals > 1].shape[0]/hosPhy.shape[0] # Percentage of doctors who work for 2 or more hospitals
print("Percent Physicians associated with two or more hospitals:\n" + '%.3f' %percent)
hosPhy[hosPhy.Hospitals > 1]
# Out:
# Percent Physicians associated with two or more hospitals:
# 0.078
#        Physician  Hospitals
# 0           None       1018
# 5      PHY311008          2
# 18     PHY311024          2
# 33     PHY311044          2
# 38     PHY311052          2
# ...          ...        ...
# 91063  PHY434037          2
# 91069  PHY434046          2
# 91079  PHY434061          2
# 91097  PHY434085          2
# 91102  PHY434092          2
#
# [7066 rows x 2 columns]

# %%
#Each patient goes to # many hospitals
hosPat = pd.DataFrame(outpatient.groupby('BeneID')['Provider'].nunique()).reset_index()
hosPat.columns = ['Patient', 'Hospital']
patperc = hosPat[hosPat.Hospital > 1].shape[0]/hosPat.shape[0] # Percentage of doctors who work for 2 or more hospitals
print("Percent Patients that go to two or more hospitals:\n" + '%.3f' %patperc)
hosPat[hosPat.Hospital > 1]
# Out:
# Percent Patients that go to two or more hospitals:
# 0.690
#            Patient  Hospital
# 1       BENE100001         7
# 2       BENE100002        11
# 4       BENE100004         4
# 5       BENE100005         2
# 6       BENE100006         2
# ...            ...       ...
# 144182   BENE99993         3
# 144183   BENE99994         3
# 144186   BENE99997         5
# 144187   BENE99998         2
# 144188   BENE99999         7
#
# [99468 rows x 2 columns]

# %%
s = outpatient['AttendingPhysician'].value_counts().nlargest(20)
s.plot.bar()
plt.title('Outpatient Medical Doctors')
# Out:
# Text(0.5, 1.0, 'Outpatient Medical Doctors')

# %%
outpatient['BeneID'].nunique()
# Out:
# 144189

# %%
b = outpatient['BeneID'].value_counts().nlargest(20)
b.plot.bar()
plt.title('Outpatients (BeneID)')
# Out:
# Text(0.5, 1.0, 'Outpatients (BeneID)')

# %%
outpatient.dtypes
# Out:
# BeneID                             object
# ClaimID                            object
# ClaimStartDt               datetime64[ns]
# ClaimEndDt                 datetime64[ns]
# Provider                           object
# InscClaimAmtReimbursed              int64
# AttendingPhysician                 object
# OperatingPhysician                 object
# OtherPhysician                     object
# ClmDiagnosisCode_1                 object
# ClmDiagnosisCode_2                 object
# ClmDiagnosisCode_3                 object
# ClmDiagnosisCode_4                 object
# ClmDiagnosisCode_5                 object
# ClmDiagnosisCode_6                 object
# ClmDiagnosisCode_7                 object
# ClmDiagnosisCode_8                 object
# ClmDiagnosisCode_9                 object
# ClmDiagnosisCode_10                object
# ClmProcedureCode_1                 object
# ClmProcedureCode_2                 object
# ClmProcedureCode_3                 object
# ...

# %%
# Make a separate column for month, change duration to integer, amount to float
